# %%
from sklearn.feature_extraction import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.feature_extraction import CountVectorizer
#
# ImportError: cannot import name 'CountVectorizer' from 'sklearn.feature_extraction' (c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\__init__.py)
